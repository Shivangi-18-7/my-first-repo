# %% [markdown]
# Hardware refers to the physical components of a computer that you can touch, such as a keyboard or monitor. Software refers to the programs or applications that run on a computer and perform tasks. For example, a keyboard is hardware, while Microsoft Word is software.
